# %% [markdown]
# # Final Project

# %%
import data_extraction

# %%
# Encode and run query to get match data for The International
query = "select * from matches
"

encoded_query = data_extraction.encode_query(query)
base_url = "https://api.opendota.com/api/explorer"
params = {"sql": encoded_query}

match_data = data_extraction.get_api_data(base_url, params=params)

# %%
match_data
# Out:
#      match_id  match_seq_num  radiant_win  start_time  duration  \
# 0  7502154550     6314171223         True  1703338195      1030
# 1    44201436       42544425         True  1348762997      2668
# 2  7525107118     6334722768        False  1704569975      1860
# 3  5319173021     4461777351         True  1585400526      2084
# 4  4162106350     3606427106        False  1539182789      2548
# 5  7549895475     6356936390        False  1705939950      2799
# 6  7502159873     6314205910         True  1703338541      1963
# 7  5992052154     5019826094         True  1620906768      1777
# 8  7181766896     6036241054         True  1685653624      2900
# 9  5990466771     5018555092         True  1620813292      1238
#
#    tower_status_radiant  tower_status_dire  barracks_status_radiant  \
# 0                  2047               1572                       63
# 1                  1796                 36                       63
# ...

# %%
league_data.loc[league_data['name'].str.contains('the international', case=False)]
# Out:
#       leagueid                                           ticket  \
# 410        600                                             None
# 767       2733                                             None
# 787      11625                                             None
# 901       4664                                             None
# 1738     15728                                             None
# 2139      4768                                             None
# 2334      5401                                             None
# 2536     65005  econ/leagues/subscriptions_westqualifier_ingame
# 2627     65004  econ/leagues/subscriptions_eastqualifier_ingame
# 3402     16839                                             None
# 3403     16843                                             None
# 3404     16844                                             None
# 3861     13256                                             None
# 4115     14268                                             None
# ...

# %%
# get the matches from the internationals

# %%
# tier the heroes

# %%
# some plots about the heroes

# %%
#teams, some background
